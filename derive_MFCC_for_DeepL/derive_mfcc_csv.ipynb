# %%
import librosa
import pandas as pd
import numpy as np
import os
import glob


def amplitude(y):
    target_db = -40  # 目标分贝值
    db = librosa.amplitude_to_db(y)
    gain = librosa.db_to_amplitude(target_db - db.mean())  # 计算增益系数
    y_agc = y * gain
    return y_agc


def extract_mfcc(wav_path, sr=44100):
    """
    从给定路径的音频文件中提取MFCC特征

    Args:
        wav_path (str): 音频文件的路径
        sr (int): 音频采样率，默认为44100

    Returns:
        numpy.ndarray: 提取的MFCC特征矩阵，维度为(n_mfcc, t)
    """
    # 设置参数
    # n_mfcc = 20  # MFCC系数的数量
    # hop_length = 512  # 每帧的时间长度
    # n_fft = 2048  # FFT窗口大小
    # y, sr = librosa.load(wav_path, sr=None)
    y, sr = librosa.load(wav_path, sr=sr)
    # 都增益为相同大小的分贝
    y = amplitude(y)
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=20)
    return mfcc.T


def mfcc_to_csv(file_path, output_path):
    mfcc_T = extract_mfcc(file_path)
    pd.DataFrame(mfcc_T).to_csv(output_path)

# %%
if __name__ == '__main__':

    # 遍历所有子文件夹
    for subdir in glob.glob('./input/audio/*'):
        # 如果当前路径是一个文件夹
        if os.path.isdir(subdir):
            print(f"处理文件夹: {subdir}")
            # 遍历文件夹中的所有音频文件
            for filepath in glob.glob(subdir + '/*.wav'):
                print(f"处理音频: {filepath}")
                subdir_name = os.path.basename(subdir)
                output_subdir = os.path.join('./output', subdir_name)
                output_path = os.path.join(output_subdir, os.path.basename(os.path.splitext(filepath)[0]) + '.csv')
                mfcc_to_csv(file_path=filepath, output_path=output_path)
# Out:
# 处理文件夹: ./input/audio\200
# 处理音频: ./input/audio\200\001-143-L-11.wav
# 处理音频: ./input/audio\200\002-127-L-11.wav
# 处理音频: ./input/audio\200\003-154-L-11.wav
# 处理音频: ./input/audio\200\004-131-L-3.wav
# 处理音频: ./input/audio\200\005-2023-04-09_05h17m42s.wav
# 处理音频: ./input/audio\200\006-163-L-2.wav
# 处理音频: ./input/audio\200\007-158-L-1.wav
# 处理音频: ./input/audio\200\008-94-L-1.wav
# 处理音频: ./input/audio\200\009-20-L-2.wav
# 处理音频: ./input/audio\200\010-M606-0829 交通声鸟叫声_26.wav
# 处理音频: ./input/audio\200\011-M606-0829 交通声鸟叫声_14.wav
# 处理音频: ./input/audio\200\012-88-L-2.wav
# 处理音频: ./input/audio\200\013-2023-04-08_17h33m32s.wav
# 处理音频: ./input/audio\200\014-131-L-7.wav
# 处理音频: ./input/audio\200\015-48-L-1.wav
# 处理音频: ./input/audio\200\016-鸟鸣小雨_03.wav
# 处理音频: ./input/audio\200\017-145-L-7.wav
# 处理音频: ./input/audio\200\018-50-L-1.wav
# 处理音频: ./input/audio\200\019-鸟鸣小雨_25.wav
# 处理音频: ./input/audio\200\020-148-L-11.wav
# 处理音频: ./input/audio\200\021-鸟鸣机械声_6.wav
# 处理音频: ./input/audio\200\022-23-L-2.wav
# 处理音频: ./input/audio\200\023-140-L-7.wav
# 处理音频: ./input/audio\200\024-大型车辆_2.wav
# 处理音频: ./input/audio\200\025-M308-1505 车声2_4.wav
# 处理音频: ./input/audio\200\026-41-L-1.wav
# 处理音频: ./input/audio\200\027-live4_03.wav
# 处理音频: ./input/audio\200\028-116-L-2.wav
# 处理音频: ./input/audio\200\029-91-L-2.wav
# 处理音频: ./input/audio\200\030-9-L-2.wav
# 处理音频: ./input/audio\200\031-143-L-4.wav
# 处理音频: ./input/audio\200\032-159-L-10.wav
# 处理音频: ./input/audio\200\033-107-L-2.wav
# 处理音频: ./input/audio\200\034-26-L-1.wav
# 处理音频: ./input/audio\200\035-34-L-2.wav
# 处理音频: ./input/audio\200\036-151-L-12.wav
# 处理音频: ./input/audio\200\037-120-L-2.wav
# 处理音频: ./input/audio\200\038-83-L-1.wav
# 处理音频: ./input/audio\200\039-12-L-2.wav
# 处理音频: ./input/audio\200\040-106-L-2.wav
# 处理音频: ./input/audio\200\041-53-L-1.wav
# 处理音频: ./input/audio\200\042-36-L-1.wav
# 处理音频: ./input/audio\200\043-live4_04.wav
# 处理音频: ./input/audio\200\044-45-L-1.wav
# 处理音频: ./input/audio\200\045-111-L-1.wav
# 处理音频: ./input/audio\200\046-56-L-2.wav
# 处理音频: ./input/audio\200\047-2023-04-09_05h18m03s.wav
# 处理音频: ./input/audio\200\048-98-L-1.wav
# 处理音频: ./input/audio\200\049-80-L-1.wav
# 处理音频: ./input/audio\200\050-35-L-1.wav
# 处理音频: ./input/audio\200\051-142-L-3.wav
# 处理音频: ./input/audio\200\052-68-L-1.wav
# 处理音频: ./input/audio\200\053-live4_07.wav
# 处理音频: ./input/audio\200\054-129-L-3.wav
# 处理音频: ./input/audio\200\055-51-L-2.wav
# 处理音频: ./input/audio\200\056-live2_02.wav
# 处理音频: ./input/audio\200\057-33-L-2.wav
# 处理音频: ./input/audio\200\058-151-L-5.wav
# 处理音频: ./input/audio\200\059-170-L-5.wav
# 处理音频: ./input/audio\200\060-100-L-1.wav
# 处理音频: ./input/audio\200\061-126-L-2.wav
# 处理音频: ./input/audio\200\062-138-L-5.wav
# 处理音频: ./input/audio\200\063-128-L-7.wav
# 处理音频: ./input/audio\200\064-2023-04-08_17h34m52s.wav
# 处理音频: ./input/audio\200\065-60-L-1.wav
# 处理音频: ./input/audio\200\066-95-L-2.wav
# 处理音频: ./input/audio\200\067-166-L-8.wav
# 处理音频: ./input/audio\200\068-31-L-2.wav
# 处理音频: ./input/audio\200\069-27-L-1.wav
# 处理音频: ./input/audio\200\070-M606-0829 交通声鸟叫声_24.wav
# 处理音频: ./input/audio\200\071-85-L-2.wav
# 处理音频: ./input/audio\200\072-159-L-2.wav
# 处理音频: ./input/audio\200\073-123-L-1.wav
# 处理音频: ./input/audio\200\074-92-L-2.wav
# 处理音频: ./input/audio\200\075-M606-0829 交通声_1.wav
# 处理音频: ./input/audio\200\076-M406-1016 喧闹声生活声1_1.wav
# 处理音频: ./input/audio\200\077-鸟鸣小雨_08.wav
# 处理音频: ./input/audio\200\078-2023-04-08_17h34m12s.wav
# 处理音频: ./input/audio\200\079-4-L-2.wav
# 处理音频: ./input/audio\200\080-141-L-11.wav
# 处理音频: ./input/audio\200\081-42-L-1.wav
# 处理音频: ./input/audio\200\082-74-L-1.wav
# 处理音频: ./input/audio\200\083-21-L-2.wav
# 处理音频: ./input/audio\200\084-101-L-2.wav
# 处理音频: ./input/audio\200\085-63-L-2.wav
# 处理音频: ./input/audio\200\086-5-L-2.wav
# 处理音频: ./input/audio\200\087-15-L-2.wav
# 处理音频: ./input/audio\200\088-119-L-2.wav
# 处理音频: ./input/audio\200\089-125-L-2.wav
# 处理音频: ./input/audio\200\090-135-L-3.wav
# 处理音频: ./input/audio\200\091-13-L-2.wav
# 处理音频: ./input/audio\200\092-93-L-2.wav
# 处理音频: ./input/audio\200\093-虫鸣行驶声_1.wav
# 处理音频: ./input/audio\200\094-大型车辆_1.wav
# 处理音频: ./input/audio\200\095-140-L-2.wav
# 处理音频: ./input/audio\200\096-25-L-1.wav
# 处理音频: ./input/audio\200\097-52-L-2.wav
# 处理音频: ./input/audio\200\098-135-L-7.wav
# 处理音频: ./input/audio\200\099-152-L-11.wav
# 处理音频: ./input/audio\200\100-100-L-2.wav
# 处理音频: ./input/audio\200\101-22-L-2.wav
# 处理音频: ./input/audio\200\102-129-L-11.wav
# 处理音频: ./input/audio\200\103-154-L-1.wav
# 处理音频: ./input/audio\200\104-66-L-1.wav
# 处理音频: ./input/audio\200\105-32-L-2.wav
# 处理音频: ./input/audio\200\106-29-L-2.wav
# 处理音频: ./input/audio\200\107-75-L-2.wav
# 处理音频: ./input/audio\200\108-28-L-2.wav
# 处理音频: ./input/audio\200\109-65-L-1.wav
# 处理音频: ./input/audio\200\110-153-L-4.wav
# 处理音频: ./input/audio\200\111-46-L-1.wav
# 处理音频: ./input/audio\200\112-147-L-5.wav
# 处理音频: ./input/audio\200\113-139-L-8.wav
# 处理音频: ./input/audio\200\114-178-L-1.wav
# 处理音频: ./input/audio\200\115-165-L-4.wav
# 处理音频: ./input/audio\200\116-61-L-2.wav
# 处理音频: ./input/audio\200\117-81-L-1.wav
# 处理音频: ./input/audio\200\118-144-L-12.wav
# 处理音频: ./input/audio\200\119-鸟鸣机械声_5.wav
# 处理音频: ./input/audio\200\120-70-L-2.wav
# 处理音频: ./input/audio\200\121-132-L-5.wav
# 处理音频: ./input/audio\200\122-113-L-2.wav
# 处理音频: ./input/audio\200\123-133-L-2.wav
# 处理音频: ./input/audio\200\124-30-L-2.wav
# 处理音频: ./input/audio\200\125-6-L-2.wav
# 处理音频: ./input/audio\200\126-118-L-2.wav
# 处理音频: ./input/audio\200\127-136-L-11.wav
# 处理音频: ./input/audio\200\128-78-L-2.wav
# 处理音频: ./input/audio\200\129-167-L-12.wav
# 处理音频: ./input/audio\200\130-16-L-2.wav
# 处理音频: ./input/audio\200\131-8-L-2.wav
# 处理音频: ./input/audio\200\132-109-L-1.wav
# 处理音频: ./input/audio\200\133-160-L-11.wav
# 处理音频: ./input/audio\200\134-M605-0831 打桩声_01.wav
# 处理音频: ./input/audio\200\135-71-L-1.wav
# 处理音频: ./input/audio\200\136-44-L-2.wav
# 处理音频: ./input/audio\200\137-M308-1505 车声1_1.wav
# 处理音频: ./input/audio\200\138-39-L-2.wav
# 处理音频: ./input/audio\200\139-2023-04-09_05h18m32s.wav
# 处理音频: ./input/audio\200\140-141-L-4.wav
# 处理音频: ./input/audio\200\141-136-L-3.wav
# 处理音频: ./input/audio\200\142-M308-1505 锯钢管声混杂车声雨声_02.wav
# 处理音频: ./input/audio\200\143-108-L-2.wav
# 处理音频: ./input/audio\200\144-7-L-2.wav
# 处理音频: ./input/audio\200\145-86-L-2.wav
# 处理音频: ./input/audio\200\146-24-L-1.wav
# 处理音频: ./input/audio\200\147-布谷鸟生活声_11.wav
# 处理音频: ./input/audio\200\148-149-L-8.wav
# 处理音频: ./input/audio\200\149-110-L-1.wav
# 处理音频: ./input/audio\200\150-38-L-1.wav
# 处理音频: ./input/audio\200\151-155-L-12.wav
# 处理音频: ./input/audio\200\152-布谷鸟生活声_19.wav
# 处理音频: ./input/audio\200\153-90-L-1.wav
# 处理音频: ./input/audio\200\154-161-L-5.wav
# 处理音频: ./input/audio\200\155-11-L-2.wav
# 处理音频: ./input/audio\200\156-19-L-2.wav
# 处理音频: ./input/audio\200\157-虫鸣行驶声_6.wav
# 处理音频: ./input/audio\200\158-M309-0812 交通声_8.wav
# 处理音频: ./input/audio\200\159-10-L-2.wav
# 处理音频: ./input/audio\200\160-138-L-11.wav
# 处理音频: ./input/audio\200\161-124-L-1.wav
# 处理音频: ./input/audio\200\162-115-L-2.wav
# 处理音频: ./input/audio\200\163-104-L-1.wav
# 处理音频: ./input/audio\200\164-130-L-5.wav
# 处理音频: ./input/audio\200\165-M308-1505 锯钢管声混杂车声雨声_01.wav
# 处理音频: ./input/audio\200\166-105-L-1.wav
# 处理音频: ./input/audio\200\167-live2_30.wav
# 处理音频: ./input/audio\200\168-1-L-1.wav
# 处理音频: ./input/audio\200\169-117-L-2.wav
# 处理音频: ./input/audio\200\170-M309-0812 交通声_6.wav
# 处理音频: ./input/audio\200\171-17-L-1.wav
# 处理音频: ./input/audio\200\172-144-L-7.wav
# 处理音频: ./input/audio\200\173-虫鸣行驶声_5.wav
# 处理音频: ./input/audio\200\174-73-L-1.wav
# 处理音频: ./input/audio\200\175-134-L-1.wav
# 处理音频: ./input/audio\200\176-43-L-1.wav
# 处理音频: ./input/audio\200\177-128-L-10.wav
# 处理音频: ./input/audio\200\178-49-L-1.wav
# 处理音频: ./input/audio\200\179-97-L-1.wav
# 处理音频: ./input/audio\200\180-127-L-8.wav
# 处理音频: ./input/audio\200\181-37-L-1.wav
# 处理音频: ./input/audio\200\182-construction1_01.wav
# 处理音频: ./input/audio\200\183-47-L-1.wav
# 处理音频: ./input/audio\200\184-82-L-1.wav
# 处理音频: ./input/audio\200\185-M308-1505 车声2_1.wav
# 处理音频: ./input/audio\200\186-40-L-2.wav
# 处理音频: ./input/audio\200\187-89-L-2.wav
# 处理音频: ./input/audio\200\188-151-L-1.wav
# 处理音频: ./input/audio\200\189-157-L-1.wav
# 处理音频: ./input/audio\200\190-鸟鸣机械声_4.wav
# 处理音频: ./input/audio\200\191-M406-1016 喧闹声生活声2_18.wav
# 处理音频: ./input/audio\200\192-169-L-1.wav
# 处理音频: ./input/audio\200\193-14-L-2.wav
# 处理音频: ./input/audio\200\194-54-L-2.wav
# 处理音频: ./input/audio\200\195-18-L-2.wav
# 处理音频: ./input/audio\200\196-construction2_08.wav
# 处理音频: ./input/audio\200\197-103-L-1.wav
# 处理音频: ./input/audio\200\198-2-L-2.wav
# 处理音频: ./input/audio\200\199-3-L-2.wav
# 处理音频: ./input/audio\200\200-137-L-9.wav
# 处理文件夹: ./input/audio\80
# 处理音频: ./input/audio\80\ba1-M301-1731.wav
# 处理音频: ./input/audio\80\ba10-M311-1416.wav
# 处理音频: ./input/audio\80\ba11-M312-0710.wav
# 处理音频: ./input/audio\80\ba12-N301-1712.wav
# 处理音频: ./input/audio\80\ba13-N302-0729.wav
# 处理音频: ./input/audio\80\ba2-M302-0823.wav
# 处理音频: ./input/audio\80\ba3-M303-0743.wav
# 处理音频: ./input/audio\80\ba4-M304-1030.wav
# 处理音频: ./input/audio\80\ba5-M306-0708.wav
# 处理音频: ./input/audio\80\ba6-M307-0731.wav
# 处理音频: ./input/audio\80\ba7-M308-1505.wav
# 处理音频: ./input/audio\80\ba8-M309-0812.wav
# 处理音频: ./input/audio\80\ba9-M310-0745.wav
# 处理音频: ./input/audio\80\dp1-M101-1713.wav
# 处理音频: ./input/audio\80\dp10-N109-1012.wav
# 处理音频: ./input/audio\80\dp11-N113-0950.wav
# 处理音频: ./input/audio\80\dp12-N118-1630.wav
# 处理音频: ./input/audio\80\dp13-N119-1950.wav
# 处理音频: ./input/audio\80\dp14-N121-1910.wav
# 处理音频: ./input/audio\80\dp15-N124-1449.wav
# 处理音频: ./input/audio\80\dp16-N126-1515.wav
# 处理音频: ./input/audio\80\dp2-M102-0638.wav
# 处理音频: ./input/audio\80\dp3-M103-1658.wav
# 处理音频: ./input/audio\80\dp4-M107-0752.wav
# 处理音频: ./input/audio\80\dp5-M109-0700.wav
# 处理音频: ./input/audio\80\dp6-M114-2150.wav
# 处理音频: ./input/audio\80\dp7-N103-1531.wav
# 处理音频: ./input/audio\80\dp8-N105-0620.wav
# 处理音频: ./input/audio\80\dp9-N106-0628.wav
# 处理音频: ./input/audio\80\ft1-M201-0645.wav
# 处理音频: ./input/audio\80\ft10-N201-0719.wav
# 处理音频: ./input/audio\80\ft11-N202-0716.wav
# 处理音频: ./input/audio\80\ft12-N203-0819.wav
# 处理音频: ./input/audio\80\ft13-N205-1731.wav
# 处理音频: ./input/audio\80\ft2-M202-1005.wav
# 处理音频: ./input/audio\80\ft3-M203-1038.wav
# 处理音频: ./input/audio\80\ft4-M204-1609.wav
# 处理音频: ./input/audio\80\ft5-M206-0726.wav
# 处理音频: ./input/audio\80\ft6-M207-1733.wav
# 处理音频: ./input/audio\80\ft7-M208-0746.wav
# 处理音频: ./input/audio\80\ft8-M210-0643.wav
# 处理音频: ./input/audio\80\ft9-M211-1202.wav
# 处理音频: ./input/audio\80\lg1-M401-1055.wav
# 处理音频: ./input/audio\80\lg10-N404-1620.wav
# 处理音频: ./input/audio\80\lg2-M402-1450.wav
# 处理音频: ./input/audio\80\lg3-M404-0830.wav
# 处理音频: ./input/audio\80\lg4-M405-1915.wav
# 处理音频: ./input/audio\80\lg5-M406-1016.wav
# 处理音频: ./input/audio\80\lg6-M407-1936.wav
# 处理音频: ./input/audio\80\lg7-N401-1550.wav
# 处理音频: ./input/audio\80\lg8-N402-0820.wav
# 处理音频: ./input/audio\80\lg9-N403-1618.wav
# 处理音频: ./input/audio\80\lh1-M501-1825.wav
# 处理音频: ./input/audio\80\lh10-N501-0819.wav
# 处理音频: ./input/audio\80\lh11-N502-1256.wav
# 处理音频: ./input/audio\80\lh12-N503-1302.wav
# 处理音频: ./input/audio\80\lh13-N504-1148.wav
# 处理音频: ./input/audio\80\lh2-M502-0915.wav
# 处理音频: ./input/audio\80\lh3-M503-1412.wav
# 处理音频: ./input/audio\80\lh4-M504-0941.wav
# 处理音频: ./input/audio\80\lh5-M505-1001.wav
# 处理音频: ./input/audio\80\lh6-M506-1359.wav
# 处理音频: ./input/audio\80\lh7-M508-0830.wav
# 处理音频: ./input/audio\80\lh8-M509-1336.wav
# 处理音频: ./input/audio\80\lh9-M510-1751.wav
# 处理音频: ./input/audio\80\ns1-M601-1715.wav
# 处理音频: ./input/audio\80\ns10-M610-1140.wav
# 处理音频: ./input/audio\80\ns11-N601-1050.wav
# 处理音频: ./input/audio\80\ns12-N602-0859.wav
# 处理音频: ./input/audio\80\ns13-N603-1527.wav
# 处理音频: ./input/audio\80\ns14-N604-1029.wav
# 处理音频: ./input/audio\80\ns15-N605-1056.wav
# 处理音频: ./input/audio\80\ns2-M602-0806.wav
# 处理音频: ./input/audio\80\ns3-M603-0731.wav
# 处理音频: ./input/audio\80\ns4-M604-0751.wav
# 处理音频: ./input/audio\80\ns5-M605-0831.wav
# 处理音频: ./input/audio\80\ns6-M606-0829.wav
# 处理音频: ./input/audio\80\ns7-M607-1508.wav
# 处理音频: ./input/audio\80\ns8-M608-1846.wav
# 处理音频: ./input/audio\80\ns9-M609-0739.wav
# 处理文件夹: ./input/audio\83
# 处理音频: ./input/audio\83\01-1-1.wav
# 处理音频: ./input/audio\83\02-4-2.wav
# 处理音频: ./input/audio\83\03-M202-1415 ( 270-280 s).wav
# 处理音频: ./input/audio\83\04-410-1 ( 0.00-300.58 s).wav
# 处理音频: ./input/audio\83\05-10-1.wav
# 处理音频: ./input/audio\83\06-14-1.wav
# 处理音频: ./input/audio\83\07-27-1.wav
# 处理音频: ./input/audio\83\08-28-1.wav
# 处理音频: ./input/audio\83\09-31-2.wav
# 处理音频: ./input/audio\83\10-32-1.wav
# 处理音频: ./input/audio\83\11-M112-0800 (5-15s).wav
# 处理音频: ./input/audio\83\12-37-1.wav
# 处理音频: ./input/audio\83\13-M204-1446 ( 0.00-300.00 s).wav
# 处理音频: ./input/audio\83\14-413-4 ( 0.00-300.08 s).wav
# 处理音频: ./input/audio\83\15-47-1.wav
# 处理音频: ./input/audio\83\16-50-1.wav
# 处理音频: ./input/audio\83\17-53-1.wav
# 处理音频: ./input/audio\83\18-M112-0800 (50-60s).wav
# 处理音频: ./input/audio\83\19-67-1.wav
# 处理音频: ./input/audio\83\20-70-1.wav
# 处理音频: ./input/audio\83\21-77-1.wav
# 处理音频: ./input/audio\83\22-110-1.wav
# 处理音频: ./input/audio\83\23-M208-0746 ( 0.00-300.00 s).wav
# 处理音频: ./input/audio\83\24-413-9 ( 0.00-300.08 s).wav
# 处理音频: ./input/audio\83\25-M202-1415 ( 130-140 s).wav
# 处理音频: ./input/audio\83\26-128-12.wav
# 处理音频: ./input/audio\83\27-131-1.wav
# 处理音频: ./input/audio\83\28-133-8.wav
# 处理音频: ./input/audio\83\29-142-1.wav
# 处理音频: ./input/audio\83\30-149-1.wav
# 处理音频: ./input/audio\83\31-186-7.wav
# 处理音频: ./input/audio\83\32-186-预实验29号.wav
# 处理音频: ./input/audio\83\33-M209-0820 ( 40-50 s).wav
# 处理音频: ./input/audio\83\34-420-2 ( 0.00-300.58 s).wav
# 处理音频: ./input/audio\83\35-221-9.wav
# 处理音频: ./input/audio\83\36-227-6.wav
# 处理音频: ./input/audio\83\37-244-8.wav
# 处理音频: ./input/audio\83\38-251-7.wav
# 处理音频: ./input/audio\83\39-281-7.wav
# 处理音频: ./input/audio\83\40-295-5.wav
# 处理音频: ./input/audio\83\41-303-3.wav
# 处理音频: ./input/audio\83\42-312-11.wav
# 处理音频: ./input/audio\83\43-M209-0820 ( 60-70 s).wav
# 处理音频: ./input/audio\83\44-427-1.wav
# 处理音频: ./input/audio\83\45-321-9 ( 0.00-300.00 s).wav
# 处理音频: ./input/audio\83\46-324-4 ( 0.00-300.08 s).wav
# 处理音频: ./input/audio\83\47-338-3.wav
# 处理音频: ./input/audio\83\48-360-2.wav
# 处理音频: ./input/audio\83\49-365-1 ( 0.00-300.58 s).wav
# 处理音频: ./input/audio\83\50-407-9 ( 0.00-300.58 s).wav
# 处理音频: ./input/audio\83\51-409-3.wav
# 处理音频: ./input/audio\83\52-M609-1139 ( 0.00-300.00 s).wav
# 处理音频: ./input/audio\83\53-8-1.wav
# 处理音频: ./input/audio\83\54-43-1.wav
# 处理音频: ./input/audio\83\55-127-1.wav
# 处理音频: ./input/audio\83\56-216-10.wav
# 处理音频: ./input/audio\83\57-321-7 ( 0.00-300.00 s).wav
# 处理音频: ./input/audio\83\58-435-1.wav
# 处理音频: ./input/audio\83\59-437-12.wav
# 处理音频: ./input/audio\83\60-7-1.wav
# 处理音频: ./input/audio\83\61-441-2.wav
# 处理音频: ./input/audio\83\62-443-4.wav
# 处理音频: ./input/audio\83\63-444-8.wav
# 处理音频: ./input/audio\83\64-450-11.wav
# 处理音频: ./input/audio\83\65-454-6.wav
# 处理音频: ./input/audio\83\66-527-5.wav
# 处理音频: ./input/audio\83\67-555-5.wav
# 处理音频: ./input/audio\83\68-607-1.wav
# 处理音频: ./input/audio\83\69-615-7.wav
# 处理音频: ./input/audio\83\70-657-2 ( 0.00-300.00 s).wav
# 处理音频: ./input/audio\83\71-665-4.wav
# 处理音频: ./input/audio\83\72-684-9.wav
# 处理音频: ./input/audio\83\73-699-11.wav
# 处理音频: ./input/audio\83\74-438-3.wav
# 处理音频: ./input/audio\83\75-40-1.wav
# 处理音频: ./input/audio\83\76-112-1.wav
# 处理音频: ./input/audio\83\77-201-2.wav
# 处理音频: ./input/audio\83\78-313-9.wav
# 处理音频: ./input/audio\83\79-409-5.wav
# 处理音频: ./input/audio\83\80-N118-1630 ( 0.00-60.00 s).wav
# 处理音频: ./input/audio\83\81-N401-0900.wav
# 处理音频: ./input/audio\83\82-N402-1744.wav
# 处理音频: ./input/audio\83\83-N601-0847 ( 0.00-300.00 s).wav
